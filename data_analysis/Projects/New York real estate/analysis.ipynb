# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

rentals = pd.read_csv('streeteasy.csv')

# %%
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.head(5)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Visualizing Quantitative variables (rent prices)

# %%
# Box plot that shows min, max, and spread of rent prices in NYC
sns.boxplot(x='rent', data=rentals)
plt.show()

# %%
# histogram to show right skewed distribution
sns.displot(rentals.rent, bins=30, kde=True)
plt.show()

# %% [markdown]
# # Visualizing Categorical variables

# %%
sns.countplot(x='borough', data=rentals, palette='winter', hue='borough')
plt.show()

# %% [markdown]
# ### Relationship between one quantitative variable and one categorical variable

# %%
# side-by-side box plots
sns.boxplot(x='borough', y='rent', data=rentals, palette='Accent', hue='borough')
plt.show()

# %%
# Overlapping histogram of rent prices in Manhattan, Queens, and Brooklyn
plt.hist(rentals.rent[rentals.borough=='Manhattan'], label='Manhattan', density=True, alpha=.5)
plt.hist(rentals.rent[rentals.borough=='Queens'], label='Queens', density=True, alpha=.5)
plt.hist(rentals.rent[rentals.borough=='Brooklyn'], label='Brooklyn', density=True, alpha=.5)
plt.legend()
plt.show()

# %% [markdown]
# # Two Quantitative variables

# %%
# Comparing square footage and rent price
sns.scatterplot(x=rentals.size_sqft, y=rentals.rent)
plt.show()

# %% [markdown]
# # Two Categorical variables

# %%
# side-by-side bar plots
sns.countplot(x='has_elevator', hue='has_gym', data=rentals)
plt.show()

# %%
def twos_difference(lst): 
    # your code here
    yuh = []
    for i in range(len(lst)):
        for j in range(i, len(lst)):
            print(lst[i],lst[j])
            if lst[j] - lst[i] == 2:
                yuh.append((lst[i], lst[j]))
            elif lst[i] - lst[j] == 2:
                yuh.append((lst[j], lst[i]))


    return yuh

# %%
twos_difference([4, 1, 2, 3])
# Out:
# 4 4
# 4 1
# 4 2
# 4 3
# 1 1
# 1 2
# 1 3
# 2 2
# 2 3
# 3 3
# [(2, 4), (1, 3)]
